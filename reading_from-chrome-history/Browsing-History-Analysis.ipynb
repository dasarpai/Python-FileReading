# %%
# Get the list of All Columns from from any SQL Lite Table
import os
import sqlite3

data_path = os.path.expanduser('C:/Users/admin/AppData/Local/Google/Chrome/User Data/Default')
files = os.listdir(data_path)
history_db = os.path.join(data_path, 'History - Copy')

#querying the db
c = sqlite3.connect(history_db)
cursor = c.cursor()

select_statement='PRAGMA table_info(urls)'
cursor.execute(select_statement)

results = cursor.fetchall() #list of tuples
results
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1),
#  (1, 'url', 'LONGVARCHAR', 0, None, 0),
#  (2, 'title', 'LONGVARCHAR', 0, None, 0),
#  (3, 'visit_count', 'INTEGER', 1, '0', 0),
#  (4, 'typed_count', 'INTEGER', 1, '0', 0),
#  (5, 'last_visit_time', 'INTEGER', 1, None, 0),
#  (6, 'hidden', 'INTEGER', 1, '0', 0)]

# %%
import os
import sqlite3
import operator
from collections import OrderedDict
import matplotlib.pyplot as plt

def parse(url):
    try:
        parsed_url_components = url.split('//')
        sublevel_split = parsed_url_components[1].split('/', 1)
        domain = sublevel_split[0].replace("www.", "")
        return domain
    except IndexError:
        print ("URL format error!")

def analyze(results):

    #prompt = raw_input("[.] Type <c> to print or <p> to plot\n[>] ")
    prompt ="c"
    alllinks=[]
    if prompt == "c":
        for site, count in sites_count_sorted.items():
            alllinks.append( (site, count))
    elif prompt == "p":
        plt.bar(range(len(results)), results.values(), align='edge')
        plt.xticks(rotation=45)
        plt.xticks(range(len(results)), results.keys())
        plt.show()
    else:
        print ("[.] Uh?")
        quit()
    return alllinks
#path to user's history database (Chrome)
#data_path = os.path.expanduser('C:\Users\admin\AppData\Local\Google\Chrome\User Data\Default')
data_path = os.path.expanduser('C:/Users/admin/AppData/Local/Google/Chrome/User Data/Default')

files = os.listdir(data_path)

history_db = os.path.join(data_path, 'History - Copy')

#querying the db
c = sqlite3.connect(history_db)
cursor = c.cursor()
select_statement = "SELECT urls.url, urls.visit_count FROM urls, visits WHERE urls.id = visits.url;"
cursor.execute(select_statement)

results = cursor.fetchall() #tuple

sites_count = {} #dict makes iterations easier :D

for url, count in results:
    #url = parse(url)
    if url in sites_count:
        sites_count[url] += 1
    else:
        sites_count[url] = 1

sites_count_sorted = OrderedDict(sorted(sites_count.items(), key=operator.itemgetter(1), reverse=True))

links = analyze (sites_count_sorted)

fo=open(r'D:/18-DS/Browsing-History-Analysis2.csv',mode='a',encoding='utf-8')
for i in links:
    fo.write( i[0]+'\t'+str(i[1])+'\n')
fo.close()

# %%
fo.close()

# %%
print("{}".format(links))
# Out:
# [('https://docs.google.com/spreadsheets/d/1702XE4ybAV6OvDCh5JLfU_z235friMUFNgz551DhewQ/edit#gid=1810457515', 241), ('https://docs.google.com/spreadsheets/d/1702XE4ybAV6OvDCh5JLfU_z235friMUFNgz551DhewQ/edit#gid=1565031272', 144), ('https://docs.google.com/spreadsheets/d/1LiOAkCWINRsl47Mcebs_PirobItaepmKj3lEPsyTXIs/edit#gid=305438703', 127), ('https://docs.google.com/spreadsheets/d/1hl_d0QQ8ncXTW-f2ecKsU2zRNgRBI0j2Y8Hi0GCeSqY/edit#gid=0', 111), ('https://www.google.com/', 93), ('https://docs.google.com/spreadsheets/d/1LiOAkCWINRsl47Mcebs_PirobItaepmKj3lEPsyTXIs/edit#gid=1363476678', 70), ('https://docs.google.com/spreadsheets/d/1LiOAkCWINRsl47Mcebs_PirobItaepmKj3lEPsyTXIs/edit#gid=896814887', 67), ('https://docs.google.com/spreadsheets/d/1LiOAkCWINRsl47Mcebs_PirobItaepmKj3lEPsyTXIs/edit#gid=258960513', 61), ('https://docs.google.com/spreadsheets/d/1702XE4ybAV6OvDCh5JLfU_z235friMUFNgz551DhewQ/edit#gid=586375554', 58), ('https://www.dailymail.co.uk/news/article-2211046/Muslims-set-temple
# ...

# %%
len(results)
# Out:
# 5170

# %%
results[5]
# Out:
# (276,
#  'https://mail.google.com/mail/u/0/?pli=1#',
#  'Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail',
#  2,
#  0,
#  13195032440072598,
#  0,
#  6,
#  276,
#  13195032440072598,
#  0,
#  1073741824,
#  0,
#  0,
#  0)

# %%
for res in results:
    print(res[2])
# Out:
# Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Vedavit Project Solutions Mail
# Vedavit Project Solutions Mail
# Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Programming in R | upGrad
#
#
#
#
# Intermediate R | upGrad
# All Modules - Pre-Launch Preparatory Content | upGrad
# Live Session | upGrad
# Live Session | upGrad
# Live Session | upGrad
# https://learn.upgrad.com/login?redirect=learn.upgrad.com/v/course/258/session/29275/segment/154087&
# Live Session | upGrad
# Rare Mentors - Introducing your primary contact in VMEdu - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Inbox (3,240) - hari.prasad@vedavit-ps.com - Vedavit Project Solutions Mail
# Home
# Home
# Home
# ...

# %%
sites_count = {} #dict makes iterations easier :D

for url, count in results:
    url = parse(url)
    if url in sites_count:
        sites_count[url] += 1
    else:
        sites_count[url] = 1

# %%
sites_count_sorted = OrderedDict(sorted(sites_count.items(), key=operator.itemgetter(1), reverse=True))

# %%
plt.bar(range(len(sites_count_sorted)), sites_count_sorted.values(), align='edge')
plt.xticks(rotation=45)
plt.xticks(range(len(sites_count_sorted)), sites_count_sorted.keys())
plt.show()
