# %%
# importing matplotlib modules 
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 

  
# Read Images 
img = mpimg.imread('companies.png') 
  
# Output Images 
plt.figure(figsize=(25,8))
plt.imshow(img)
